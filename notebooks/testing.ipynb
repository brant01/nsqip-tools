# %%
# --- Ensure correct root path for imports and relative paths ---
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root / "src") not in sys.path:
    sys.path.insert(0, str(project_root / "src"))

# --- Set up logging ---
from nsqip_tools.utils.logging_utils import setup_logging
setup_logging("notebook")
# Out:
# 2025-05-04 16:06:43,860 - INFO - Logging initialized. Log file: logs\notebook_20250504_160643.log

# %%
from nsqip_tools.data_ingest.create_db import create_db
create_db(data_dir=Path("../data/adult"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from nsqip_tools.db_utils.create_db import create_db
#       2 create_db(data_dir=Path("../data/adult"))
#
# ModuleNotFoundError: No module named 'nsqip_tools.db_utils.create_db'
