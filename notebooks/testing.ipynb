# %%
# --- Ensure correct root path for imports and relative paths ---
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root / "src") not in sys.path:
    sys.path.insert(0, str(project_root / "src"))

# --- Set up logging ---
from nsqip_tools.utils.logging_utils import setup_logging
setup_logging("notebook")
# Out:
# 2025-05-05 06:19:26,819 - INFO - Logging initialized. Log file: logs\notebook_20250505_061926.log

# %%
from nsqip_tools.data_ingest.create_db import create_db
create_db(data_dir=Path("../data/adult"))

#comment for change
# Out:
# 2025-05-05 06:19:26,865 - INFO - Logging initialized. Log file: logs\create_db_20250505_061926.log
# 2025-05-05 06:19:26,866 - INFO - Starting database creation process.
# 2025-05-05 06:19:26,868 - INFO - Detected dataset type: nsqip
# 2025-05-05 06:19:26,869 - INFO - Found 17 files to process in ..\data\adult
# 2025-05-05 06:19:26,870 - INFO - Output database path: ..\data\adult\nsqip_data.duckdb
# 2025-05-05 06:19:26,871 - INFO - Setup complete. Proceeding to file parsing and database construction.
# 2025-05-05 06:19:27,098 - INFO - Unified column set has 348 columns.
# 2025-05-05 06:19:27,135 - INFO - Connected to DuckDB at ..\data\adult\nsqip_data.duckdb
# 2025-05-05 06:19:27,443 - INFO - Dropping existing table all_data_table if it exists.
# 2025-05-05 06:19:27,447 - INFO - Created table all_data_table with 348 columns.
# 2025-05-05 06:19:27,448 - INFO - [1/17] Processing ACS_NSQIP_PUF07_TXT.txt
# ...

# %%
from nsqip_tools.data_ingest.create_db import create_db
create_db(data_dir=Path("../data/peds"))
# Out:
# 2025-05-05 06:51:10,053 - INFO - Logging initialized. Log file: logs\create_db_20250505_065110.log
# 2025-05-05 06:51:10,055 - INFO - Starting database creation process.
# 2025-05-05 06:51:10,057 - INFO - Detected dataset type: peds
# 2025-05-05 06:51:10,058 - INFO - Found 12 files to process in ..\data\peds
# 2025-05-05 06:51:10,059 - INFO - Output database path: ..\data\peds\peds_data.duckdb
# 2025-05-05 06:51:10,060 - INFO - Setup complete. Proceeding to file parsing and database construction.
# 2025-05-05 06:51:10,305 - INFO - Unified column set has 414 columns.
# 2025-05-05 06:51:10,341 - INFO - Connected to DuckDB at ..\data\peds\peds_data.duckdb
# 2025-05-05 06:51:10,383 - INFO - Dropping existing table all_data_table if it exists.
# 2025-05-05 06:51:10,388 - INFO - Created table all_data_table with 414 columns.
# 2025-05-05 06:51:10,388 - INFO - [1/12] Processing acs_peds_puf12.txt
# ...
