# %%
from nsqip_tools.data_ingest.create_db import create_db, get_all_columns
from pathlib import Path

# %%
data_dir = Path("../data") / "adult"
files = sorted(data_dir.glob("*.txt"))
print(data_dir.resolve())

print(f"Found {len(files)} files:")
print([f.name for f in files[:5]])
# Out:
# C:\Users\BrantLab\projects\nsqip_tools\data\adult
# Found 17 files:
# ['ACS_NSQIP_PUF07_TXT.txt', 'ACS_NSQIP_PUF08_TXT.txt', 'ACS_NSQIP_PUF09_TXT.txt', 'ACS_NSQIP_PUF10_TXT.txt', 'ACS_NSQIP_PUF11_TXT.txt']

# %%
data_dir = Path("../data/adult")  # or update if your .txt files are elsewhere
files = sorted(data_dir.glob("*.txt"))

all_columns = get_all_columns(files)

print(f"Found {len(all_columns)} total columns:")
print(all_columns[:10])  # show the first few
# Out:
# Found 348 total columns:
# ['ADMQTR', 'ADMSYR', 'ADMYR', 'AGE', 'AIRTRA', 'ANESTHES', 'ANESTHES_OTHER', 'ANESURG', 'ANETIME', 'ASACLAS']
